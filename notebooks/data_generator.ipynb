# %%
# OPTIONAL: Load the "autoreload" extension so that code can change
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

import sys, os
# sys.path.append('../src/models/')

import numpy as np

from src.models import generators
from src.models import augmentations

import matplotlib.pyplot as plt

from skimage.io import imread
# Out:
# Using TensorFlow backend.

# %%
test_generator = generators.DataGeneratorFolder(root_dir = '../data/processed/train',
                                                image_folder = 'images/', 
                                                mask_folder = 'masks/',
                                                image_size=512,
                                                batch_size = 1,
                                                nb_y_features = 1, 
                                                augmentation = augmentations.aug_with_crop
                                               )

Xtest, ytest = test_generator.__getitem__(0)

f, ax = plt.subplots(1, 2, figsize=(16, 16))
ax[0].imshow(Xtest[0])     
ax[1].imshow(ytest[0, :,:,0], cmap='gray')
plt.show()
